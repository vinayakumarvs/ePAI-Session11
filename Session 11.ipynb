# %%
def func():
    print('A good day!')
    return True

type(func)
# Out:
# function

# %%
id(func)
# Out:
# 140463406910496

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   "def func():\n    print('A good day!')\n    return True\n\ntype(func)",
#   'id(func)',
#   'globals()'],
#  '_oh': {1: function, 2: 140463406910496},
#  '_dh': ['/home/jovyan'],
#  'In': ['',
#   "def func():\n    print('A good day!')\n    return True\n\ntype(func)",
#   'id(func)',
#   'globals()'],
#  'Out': {1: function, 2: 140463406910496},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7fc05a2ccc90>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x7fc0582457d0>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x7fc0582457d0>,
#  '_': 140463406910496,
#  '__': function,
#  '___': '',
# ...

# %%
func
# Out:
# <function __main__.func()>

# %%
globals()['func']
# Out:
# <function __main__.func()>

# %%
globals()['func']()
# Out:
# A good day!
# True

# %%
globals() == locals()
# Out:
# True

# %%
a = 100
def func():
    a = 10
    b = 10
    print(locals())

func()
# Out:
# {'a': 10, 'b': 10}

# %%
import math

# %%
math
# Out:
# <module 'math' from '/usr/local/lib/python3.7/lib-dynload/math.cpython-37m-x86_64-linux-gnu.so'>

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   "def func():\n    print('A good day!')\n    return True\n\ntype(func)",
#   'id(func)',
#   'globals()',
#   'func',
#   "globals()['func']",
#   "globals()['func']()",
#   'globals() == locals()',
#   'a = 100\ndef func():\n    a = 10\n    b = 10\n    print(locals())\n\nfunc()',
#   'import math',
#   'math',
#   'globals()'],
#  '_oh': {1: function,
#   2: 140463406910496,
#   3: {...},
#   4: <function __main__.func()>,
#   5: <function __main__.func()>,
#   6: True,
#   7: True,
#   10: <module 'math' from '/usr/local/lib/python3.7/lib-dynload/math.cpython-37m-x86_64-linux-gnu.so'>},
#  '_dh': ['/home/jovyan'],
#  'In': ['',
# ...

# %%
globals()['math'].sqrt(2)
# Out:
# 1.4142135623730951

# %%
import fractions
fractions
# Out:
# <module 'fractions' from '/usr/local/lib/python3.7/fractions.py'>

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   "def func():\n    print('A good day!')\n    return True\n\ntype(func)",
#   'id(func)',
#   'globals()',
#   'func',
#   "globals()['func']",
#   "globals()['func']()",
#   'globals() == locals()',
#   'a = 100\ndef func():\n    a = 10\n    b = 10\n    print(locals())\n\nfunc()',
#   'import math',
#   'math',
#   'globals()',
#   'globals[math]',
#   'globals()[math]',
#   "globals()['math']",
#   "globals()['math'].sqrt(2)",
#   'import fractions\nfractions ',
#   'globals()'],
#  '_oh': {1: function,
#   2: 140463406910496,
#   3: {...},
#   4: <function __main__.func()>,
#   5: <function __main__.func()>,
#   6: True,
#   7: True,
# ...

# %%
type(globals())
# Out:
# dict

# %%
type(math), type(fractions)
# Out:
# (module, module)

# %%
id(math)
# Out:
# 140464187531632

# %%
import math
id(math)
# Out:
# 140464187531632

# %%
import sys

sys.modules
# Out:
# {'sys': <module 'sys' (built-in)>,
#  'builtins': <module 'builtins' (built-in)>,
#  '_frozen_importlib': <module 'importlib._bootstrap' (frozen)>,
#  '_imp': <module '_imp' (built-in)>,
#  '_thread': <module '_thread' (built-in)>,
#  '_warnings': <module '_warnings' (built-in)>,
#  '_weakref': <module '_weakref' (built-in)>,
#  'zipimport': <module 'zipimport' (built-in)>,
#  '_frozen_importlib_external': <module 'importlib._bootstrap_external' (frozen)>,
#  '_io': <module 'io' (built-in)>,
#  'marshal': <module 'marshal' (built-in)>,
#  'posix': <module 'posix' (built-in)>,
#  'encodings': <module 'encodings' from '/usr/local/lib/python3.7/encodings/__init__.py'>,
#  'codecs': <module 'codecs' from '/usr/local/lib/python3.7/codecs.py'>,
#  '_codecs': <module '_codecs' (built-in)>,
#  'encodings.aliases': <module 'encodings.aliases' from '/usr/local/lib/python3.7/encodings/aliases.py'>,
# ...

# %%
type(sys.modules)
# Out:
# dict

# %%
sys.modules['math']
# Out:
# <module 'math' from '/usr/local/lib/python3.7/lib-dynload/math.cpython-37m-x86_64-linux-gnu.so'>

# %%
sys.modules['fractions']
# Out:
# <module 'fractions' from '/usr/local/lib/python3.7/fractions.py'>

# %%
math
# Out:
# <module 'math' from '/usr/local/lib/python3.7/lib-dynload/math.cpython-37m-x86_64-linux-gnu.so'>

# %%
math.__name__
# Out:
# 'math'

# %%
__name__
# Out:
# '__main__'

# %%
math.__dict__
# Out:
# {'__name__': 'math',
#  '__doc__': 'This module provides access to the mathematical functions\ndefined by the C standard.',
#  '__package__': '',
#  '__loader__': <_frozen_importlib_external.ExtensionFileLoader at 0x7fc05e0042d0>,
#  '__spec__': ModuleSpec(name='math', loader=<_frozen_importlib_external.ExtensionFileLoader object at 0x7fc05e0042d0>, origin='/usr/local/lib/python3.7/lib-dynload/math.cpython-37m-x86_64-linux-gnu.so'),
#  'acos': <function math.acos(x, /)>,
#  'acosh': <function math.acosh(x, /)>,
#  'asin': <function math.asin(x, /)>,
#  'asinh': <function math.asinh(x, /)>,
#  'atan': <function math.atan(x, /)>,
#  'atan2': <function math.atan2(y, x, /)>,
#  'atanh': <function math.atanh(x, /)>,
#  'ceil': <function math.ceil(x, /)>,
#  'copysign': <function math.copysign(x, y, /)>,
#  'cos': <function math.cos(x, /)>,
#  'cosh': <function math.cosh(x, /)>,
#  'degrees': <function math.degrees(x, /)>,
#  'erf': <function math.erf(x, /)>,
# ...

# %%
math.__dict__['sin'](0)
# Out:
# 0.0

# %%
math.__spec__
# Out:
# ModuleSpec(name='math', loader=<_frozen_importlib_external.ExtensionFileLoader object at 0x7fc05e0042d0>, origin='/usr/local/lib/python3.7/lib-dynload/math.cpython-37m-x86_64-linux-gnu.so')

# %%
sys.modules['fractions']
# Out:
# <module 'fractions' from '/usr/local/lib/python3.7/fractions.py'>

# %%
fractions.__dict__
# Out:
# {'__name__': 'fractions',
#  '__doc__': 'Fraction, infinite-precision, real numbers.',
#  '__package__': '',
#  '__loader__': <_frozen_importlib_external.SourceFileLoader at 0x7fc0338aa7d0>,
#  '__spec__': ModuleSpec(name='fractions', loader=<_frozen_importlib_external.SourceFileLoader object at 0x7fc0338aa7d0>, origin='/usr/local/lib/python3.7/fractions.py'),
#  '__file__': '/usr/local/lib/python3.7/fractions.py',
#  '__cached__': '/usr/local/lib/python3.7/__pycache__/fractions.cpython-37.pyc',
#  '__builtins__': {'__name__': 'builtins',
#   '__doc__': "Built-in functions, exceptions, and other objects.\n\nNoteworthy: None is the `nil' object; Ellipsis represents `...' in slices.",
#   '__package__': '',
#   '__loader__': _frozen_importlib.BuiltinImporter,
#   '__spec__': ModuleSpec(name='builtins', loader=<class '_frozen_importlib.BuiltinImporter'>),
#   '__build_class__': <function __build_class__>,
#   '__import__': <function __import__>,
#   'abs': <function abs(x, /)>,
# ...

# %%
import calendar

calendar
# Out:
# <module 'calendar' from '/usr/local/lib/python3.7/calendar.py'>

# %%
import types
isinstance(fractions, types.ModuleType)
# Out:
# True

# %%
mod = types.ModuleType('test', 'THIS IS A TEST MODULE')
mod
# Out:
# <module 'test'>

# %%
isinstance(mod, types.ModuleType)
# Out:
# True

# %%
math.__dict__
# Out:
# {'__name__': 'math',
#  '__doc__': 'This module provides access to the mathematical functions\ndefined by the C standard.',
#  '__package__': '',
#  '__loader__': <_frozen_importlib_external.ExtensionFileLoader at 0x7fc05e0042d0>,
#  '__spec__': ModuleSpec(name='math', loader=<_frozen_importlib_external.ExtensionFileLoader object at 0x7fc05e0042d0>, origin='/usr/local/lib/python3.7/lib-dynload/math.cpython-37m-x86_64-linux-gnu.so'),
#  'acos': <function math.acos(x, /)>,
#  'acosh': <function math.acosh(x, /)>,
#  'asin': <function math.asin(x, /)>,
#  'asinh': <function math.asinh(x, /)>,
#  'atan': <function math.atan(x, /)>,
#  'atan2': <function math.atan2(y, x, /)>,
#  'atanh': <function math.atanh(x, /)>,
#  'ceil': <function math.ceil(x, /)>,
#  'copysign': <function math.copysign(x, y, /)>,
#  'cos': <function math.cos(x, /)>,
#  'cosh': <function math.cosh(x, /)>,
#  'degrees': <function math.degrees(x, /)>,
#  'erf': <function math.erf(x, /)>,
# ...

# %%
mod.__dict__
# Out:
# {'__name__': 'test',
#  '__doc__': 'THIS IS A TEST MODULE',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None}

# %%
mod.__dict__['sqrt'] = math.sqrt

# %%
mod.__dict__
# Out:
# {'__name__': 'test',
#  '__doc__': 'THIS IS A TEST MODULE',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  'sqrt': <function math.sqrt(x, /)>}

# %%
mod.sqrt(2)
# Out:
# 1.4142135623730951

# %%
mod.ci = 6.28

# %%
mod.__dict__
# Out:
# {'__name__': 'test',
#  '__doc__': 'THIS IS A TEST MODULE',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  'sqrt': <function math.sqrt(x, /)>,
#  'ci': 6.28}

# %%
mod.sqrt(mod.ci)
# Out:
# 2.5059928172283334

# %%
mod.pi = math.pi
mod.hello = lambda: 'Hello'

mod.__dict__
# Out:
# {'__name__': 'test',
#  '__doc__': 'THIS IS A TEST MODULE',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  'sqrt': <function math.sqrt(x, /)>,
#  'ci': 6.28,
#  'pi': 3.141592653589793,
#  'hello': <function __main__.<lambda>()>}

# %%
from math import sqrt

# %%
from mod import sqrt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-52-1d78c1f9a74a> in <module>
# ----> 1 from mod import sqrt
#
# ModuleNotFoundError: No module named 'mod'

# %% [markdown]
# When we run a statement such as
#
# import fractions
#
# what is Python actually doing?
#
# The first thing to note is that Python is doing the import at "run time", i.e. while your code is actually running.
#
# This is different from traditional compiled languages such as C where modules are compiled and linked at compile time
#
# In both cases though, the system needs to know where those code file exist
#
# Python uses a relatively complex system of how to find and load modules. We will take a brief look at the main points
#
# The sys module has a few properties that define where Python is going to look for modules (either built-in/.so of standard library as well as our own or 3rd party):

# %%
import sys

# %%
sys.prefix
# Out:
# '/opt/venv'

# %%
sys.path
# Out:
# ['/home/jovyan',
#  '/usr/local/lib/python37.zip',
#  '/usr/local/lib/python3.7',
#  '/usr/local/lib/python3.7/lib-dynload',
#  '',
#  '/opt/venv/lib/python3.7/site-packages',
#  '/opt/venv/lib/python3.7/site-packages/python_language_server-deepnote_0.03-py3.7.egg',
#  '/opt/venv/lib/python3.7/site-packages/ujson-4.0.1-py3.7-linux-x86_64.egg',
#  '/opt/venv/lib/python3.7/site-packages/pluggy-1.0.0.dev0-py3.7.egg',
#  '/opt/venv/lib/python3.7/site-packages/python_jsonrpc_server-0.4.0-py3.7.egg',
#  '/opt/venv/lib/python3.7/site-packages/IPython/extensions',
#  '/home/jovyan/.ipython',
#  '/home/jovyan/work']

# %% [markdown]
# Basically when we import a module, Python will search for the module in the paths contained in sys.path
#
# If it does not find the module in one of those paths, the import will fail.
#
# So if you ever run into a problem where Python is not able to import a module or package, you should check this first to make sure the path to you module/package is in that list.

# %% [markdown]
# At a high level, this is how Python imports a module from file:
#
# checks the sys.module cache to see if the module has already been imported - if so it simply uses the reference in these, otherwise:
# creates a new module object (types.ModuleType)
# loads the source code from file (most probably)
# adds an entry to sys.module with name as the key
# compiles and exectues the source code
# One this that's really important to note is that when a module is imported, the module code is executed

# %%
At a high level, this is how Python imports a module from file:

checks the sys.module cache to see if the module has already been imported - if so it simply uses the reference in these, otherwise:
creates a new module object (types.ModuleType)
loads the source code from file (most probably)
adds an entry to sys.module with name as the key
compiles and exectues the source code
One this that's really important to note is that when a module is imported, the module code is executed

# %%
sys.path
# Out:
# ['/home/jovyan',
#  '/usr/local/lib/python37.zip',
#  '/usr/local/lib/python3.7',
#  '/usr/local/lib/python3.7/lib-dynload',
#  '',
#  '/opt/venv/lib/python3.7/site-packages',
#  '/opt/venv/lib/python3.7/site-packages/python_language_server-deepnote_0.03-py3.7.egg',
#  '/opt/venv/lib/python3.7/site-packages/ujson-4.0.1-py3.7-linux-x86_64.egg',
#  '/opt/venv/lib/python3.7/site-packages/pluggy-1.0.0.dev0-py3.7.egg',
#  '/opt/venv/lib/python3.7/site-packages/python_jsonrpc_server-0.4.0-py3.7.egg',
#  '/opt/venv/lib/python3.7/site-packages/IPython/extensions',
#  '/home/jovyan/.ipython',
#  '/home/jovyan/work']

# %% [markdown]
# import math >> sys.modules >> globals
#
# del globals()['math'] >> removed from globals..
#
# that means import math >> throw error
#
# import math >> sys.module >> globals..

# %%
sys.modules['test'] = lambda: "testing sys"

import test

test, test()
# Out:
# (<function __main__.<lambda>()>, 'testing sys')

# %%
globals()['test']
# Out:
# <function __main__.<lambda>()>

# %%
import sys

# %%
sys
# Out:
# <module 'sys' (built-in)>

# %%
import collections

collections
# Out:
# <module 'collections' from '/usr/local/lib/python3.7/collections/__init__.py'>

# %%
user_module = input()

# %%
user_module
# Out:
# 'math'

# %%
import user_module
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-65-e1724f3d2598> in <module>
# ----> 1 import user_module
#
# ModuleNotFoundError: No module named 'user_module'

# %%
import importlib

importlib
# Out:
# <module 'importlib' from '/usr/local/lib/python3.7/importlib/__init__.py'>

# %%
globals()['math']
# Out:
# <module 'math' from '/usr/local/lib/python3.7/lib-dynload/math.cpython-37m-x86_64-linux-gnu.so'>

# %%
del globals()['math']

# %%
math.sqrt(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-71-b1a01eea6359> in <module>
# ----> 1 math.sqrt(2)
#
# NameError: name 'math' is not defined

# %%
'math' in sys.modules
# Out:
# True

# %%
'math' in globals()
# Out:
# False

# %%
math2 = importlib.import_module(user_module)

math2
# Out:
# <module 'math' from '/usr/local/lib/python3.7/lib-dynload/math.cpython-37m-x86_64-linux-gnu.so'>

# %%
globals()['math2']
# Out:
# <module 'math' from '/usr/local/lib/python3.7/lib-dynload/math.cpython-37m-x86_64-linux-gnu.so'>

# %%
fractions.__spec__
# Out:
# ModuleSpec(name='fractions', loader=<_frozen_importlib_external.SourceFileLoader object at 0x7fc0338aa7d0>, origin='/usr/local/lib/python3.7/fractions.py')

# %%
# loader >> finder + loader

# %%
sys.meta_path
# Out:
# ...
#  _frozen_importlib.BuiltinImporter,
#  _frozen_importlib.FrozenImporter,
#  _frozen_importlib_external.PathFinder,
# ...

# %%
math2.__spec__
# Out:
# ModuleSpec(name='math', loader=<_frozen_importlib_external.ExtensionFileLoader object at 0x7fc05e0042d0>, origin='/usr/local/lib/python3.7/lib-dynload/math.cpython-37m-x86_64-linux-gnu.so')

# %%
import module3
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-82-b4e6aa7db43e> in <module>
# ----> 1 import module3
#
# ModuleNotFoundError: No module named 'module3'

# %%
importlib.util.find_spec('decimal')
# Out:
# ModuleSpec(name='decimal', loader=<_frozen_importlib_external.SourceFileLoader object at 0x7fc05a3ed590>, origin='/usr/local/lib/python3.7/decimal.py')

# %%
with open('module1.py', 'w') as code_file:
    code_file.write("print('running module1.py...')\n")
    code_file.write('a=100\n')

# %%
importlib.util.find_spec('module1')
# Out:
# ModuleSpec(name='module1', loader=<_frozen_importlib_external.SourceFileLoader object at 0x7fc02c2b8450>, origin='/home/jovyan/work/module1.py')

# %%
import module1
# Out:
# running module1.py...

# %%
'module1' in globals(), module1.a
# Out:
# (True, 100)

# %%
importlib.util.find_spec('modulen')

# %%
import modulen
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-89-957a216ddb14> in <module>
# ----> 1 import modulen
#
# ModuleNotFoundError: No module named 'modulen'

# %%
sys.path
# Out:
# ['/home/jovyan',
#  '/usr/local/lib/python37.zip',
#  '/usr/local/lib/python3.7',
#  '/usr/local/lib/python3.7/lib-dynload',
#  '',
#  '/opt/venv/lib/python3.7/site-packages',
#  '/opt/venv/lib/python3.7/site-packages/python_language_server-deepnote_0.03-py3.7.egg',
#  '/opt/venv/lib/python3.7/site-packages/ujson-4.0.1-py3.7-linux-x86_64.egg',
#  '/opt/venv/lib/python3.7/site-packages/pluggy-1.0.0.dev0-py3.7.egg',
#  '/opt/venv/lib/python3.7/site-packages/python_jsonrpc_server-0.4.0-py3.7.egg',
#  '/opt/venv/lib/python3.7/site-packages/IPython/extensions',
#  '/home/jovyan/.ipython',
#  '/home/jovyan/work']

# %%
pwd
# Out:
# '/home/jovyan/work'

# %%
sys.path.append('/home/jovyan/work/Session_11/examplen')

# %%
importlib.util.find_spec('modulen')

# %%
sys.path
# Out:
# ['/home/jovyan',
#  '/usr/local/lib/python37.zip',
#  '/usr/local/lib/python3.7',
#  '/usr/local/lib/python3.7/lib-dynload',
#  '',
#  '/opt/venv/lib/python3.7/site-packages',
#  '/opt/venv/lib/python3.7/site-packages/python_language_server-deepnote_0.03-py3.7.egg',
#  '/opt/venv/lib/python3.7/site-packages/ujson-4.0.1-py3.7-linux-x86_64.egg',
#  '/opt/venv/lib/python3.7/site-packages/pluggy-1.0.0.dev0-py3.7.egg',
#  '/opt/venv/lib/python3.7/site-packages/python_jsonrpc_server-0.4.0-py3.7.egg',
#  '/opt/venv/lib/python3.7/site-packages/IPython/extensions',
#  '/home/jovyan/.ipython',
#  '/home/jovyan/work',
#  '/home/jovyan/work/Session_11/examplen',
#  '/home/jovyan/work/Session_11/examplen',
#  '/home/jovyan/work/Session_11/examplen']

# %%
import modulen
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-102-957a216ddb14> in <module>
# ----> 1 import modulen
#
# ModuleNotFoundError: No module named 'modulen'

# %%
sys.path
# Out:
# ['/home/jovyan',
#  '/usr/local/lib/python37.zip',
#  '/usr/local/lib/python3.7',
#  '/usr/local/lib/python3.7/lib-dynload',
#  '',
#  '/opt/venv/lib/python3.7/site-packages',
#  '/opt/venv/lib/python3.7/site-packages/python_language_server-deepnote_0.03-py3.7.egg',
#  '/opt/venv/lib/python3.7/site-packages/ujson-4.0.1-py3.7-linux-x86_64.egg',
#  '/opt/venv/lib/python3.7/site-packages/pluggy-1.0.0.dev0-py3.7.egg',
#  '/opt/venv/lib/python3.7/site-packages/python_jsonrpc_server-0.4.0-py3.7.egg',
#  '/opt/venv/lib/python3.7/site-packages/IPython/extensions',
#  '/home/jovyan/.ipython',
#  '/home/jovyan/work',
#  '/home/jovyan/work/Session_11/examplen',
#  '/home/jovyan/work/Session_11/examplen',
#  '/home/jovyan/work/Session_11/examplen',
#  '/home/jovyan/work/Session_11/examplen']

# %%
importlib.util.find_spec('modulen')

# %%
import sys

# %%
for key in sorted(sys.modules.keys()):
    print(key)
# Out:
# IPython
# IPython.core
# IPython.core.alias
# IPython.core.application
# IPython.core.async_helpers
# IPython.core.autocall
# IPython.core.builtin_trap
# IPython.core.compilerop
# IPython.core.completer
# IPython.core.completerlib
# IPython.core.crashhandler
# IPython.core.debugger
# IPython.core.display
# IPython.core.display_trap
# IPython.core.displayhook
# IPython.core.displaypub
# IPython.core.error
# IPython.core.events
# IPython.core.excolors
# IPython.core.extensions
# IPython.core.formatters
# IPython.core.getipython
# IPython.core.history
# IPython.core.hooks
# IPython.core.inputtransformer2
# IPython.core.interactiveshell
# IPython.core.latex_symbols
# IPython.core.logger
# IPython.core.macro
# IPython.core.magic
# IPython.core.magic_arguments
# IPython.core.magics
# IPython.core.magics.auto
# IPython.core.magics.basic
# IPython.core.magics.code
# IPython.core.magics.config
# IPython.core.magics.display
# IPython.core.magics.execution
# IPython.core.magics.extension
# ...

# %%
'cmath' in sys.modules
# Out:
# False

# %%
import cmath
'cmath' in sys.modules
# Out:
# True

# %%
'cmath' in globals()
# Out:
# True

# %%
del globals()['cmath']
from cmath import exp
'cmath' in globals()
# Out:
# False

# %%
'exp' in globals()
# Out:
# True

# %%
exp
# Out:
# <function cmath.exp(z, /)>

# %%
exp(2+2j)
# Out:
# (-3.074932320639359+6.71884969742825j)

# %%
'cmath' in sys.modules
# Out:
# True

# %%
cmath = sys.modules['cmath']

'cmath' in globals()
# Out:
# True

# %%
cmath.pi
# Out:
# 3.141592653589793

# %%
from cmath import *

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   "def func():\n    print('A good day!')\n    return True\n\ntype(func)",
#   'id(func)',
#   'globals()',
#   'func',
#   "globals()['func']",
#   "globals()['func']()",
#   'globals() == locals()',
#   'a = 100\ndef func():\n    a = 10\n    b = 10\n    print(locals())\n\nfunc()',
#   'import math',
#   'math',
#   'globals()',
#   'globals[math]',
#   'globals()[math]',
#   "globals()['math']",
#   "globals()['math'].sqrt(2)",
#   'import fractions\nfractions ',
#   'globals()',
#   'type(globals())',
#   'type(math), type(fractions)',
#   'id(math)',
#   'import math\nid(math)',
#   'import sys\n\nsys.modules',
#   'type(sys.modules)',
#   "sys.modules['math']",
# ...

# %%
sin(2+2j)
# Out:
# (3.4209548611170133-1.5093064853236158j)

# %%
from math import sin

globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   "def func():\n    print('A good day!')\n    return True\n\ntype(func)",
#   'id(func)',
#   'globals()',
#   'func',
#   "globals()['func']",
#   "globals()['func']()",
#   'globals() == locals()',
#   'a = 100\ndef func():\n    a = 10\n    b = 10\n    print(locals())\n\nfunc()',
#   'import math',
#   'math',
#   'globals()',
#   'globals[math]',
#   'globals()[math]',
#   "globals()['math']",
#   "globals()['math'].sqrt(2)",
#   'import fractions\nfractions ',
#   'globals()',
#   'type(globals())',
#   'type(math), type(fractions)',
#   'id(math)',
#   'import math\nid(math)',
#   'import sys\n\nsys.modules',
#   'type(sys.modules)',
#   "sys.modules['math']",
# ...

# %%
sin(2+2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-123-bf68684de58d> in <module>
# ----> 1 sin(2+2j)
#
# TypeError: can't convert complex to float

# %%
from cmath import sin as c_sin
from math import sin as r_sin

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   "def func():\n    print('A good day!')\n    return True\n\ntype(func)",
#   'id(func)',
#   'globals()',
#   'func',
#   "globals()['func']",
#   "globals()['func']()",
#   'globals() == locals()',
#   'a = 100\ndef func():\n    a = 10\n    b = 10\n    print(locals())\n\nfunc()',
#   'import math',
#   'math',
#   'globals()',
#   'globals[math]',
#   'globals()[math]',
#   "globals()['math']",
#   "globals()['math'].sqrt(2)",
#   'import fractions\nfractions ',
#   'globals()',
#   'type(globals())',
#   'type(math), type(fractions)',
#   'id(math)',
#   'import math\nid(math)',
#   'import sys\n\nsys.modules',
#   'type(sys.modules)',
#   "sys.modules['math']",
# ...

# %%
def my_func(a):
    import math
    return math.sqrt(a)

# %%
from time import perf_counter

# %%
from collections import namedtuple

# %%
Timings = namedtuple('Timings', 'timing_1, timing_2, abs_diff, rel_diff_perc')

# %%
def compare_timings(timing1, timing2):
    rel_diff = (timing2 - timing1)/timing1 * 100

    timings = Timings(round(timing1, 1),
                    round(timing2, 1),
                    round(timing2-timing1, 1),
                    round(rel_diff, 2))
    return timings

# %%
compare_timings(1, 2)
# Out:
# Timings(timing_1=1, timing_2=2, abs_diff=1, rel_diff_perc=100.0)

# %%
test_repeats = 10_000_000

# %%
import math

start = perf_counter()
for _ in range(test_repeats):
    math.sqrt(2)
end = perf_counter()

elapsed_module_symbol = end - start

print(f'Elapsed: {elapsed_module_symbol}')
# Out:
# Elapsed: 2.038611344061792

# %%
from math import sqrt

start = perf_counter()
for _ in range(test_repeats):
    sqrt(2)
end = perf_counter()

elapsed_direct_symbol = end - start

print(f'Elapsed: {elapsed_direct_symbol}')
# Out:
# Elapsed: 1.2842281837947667

# %%
compare_timings(elapsed_module_symbol, elapsed_direct_symbol)
# Out:
# Timings(timing_1=2.0, timing_2=1.3, abs_diff=-0.8, rel_diff_perc=-37.0)

# %%
import math

def func():
    math.sqrt(2)


start = perf_counter()
for _ in range(test_repeats):
    func()
end = perf_counter()

elapsed_module_symbol = end - start

print(f'Elapsed: {elapsed_module_symbol}')
# Out:
# Elapsed: 2.949378945864737

# %%
from math import sqrt

def func():
    sqrt(2)


start = perf_counter()
for _ in range(test_repeats):
    func()
end = perf_counter()

elapsed_direct_symbol = end - start

print(f'Elapsed: {elapsed_direct_symbol}')
# Out:
# Elapsed: 2.0641597732901573

# %%
compare_timings(elapsed_module_symbol, elapsed_direct_symbol)
# Out:
# Timings(timing_1=2.9, timing_2=2.1, abs_diff=-0.9, rel_diff_perc=-30.01)

# %%
# nested

def func():
    import math
    math.sqrt(2)


start = perf_counter()
for _ in range(test_repeats):
    func()
end = perf_counter()

elapsed_nested_module_symbol = end - start

print(f'Elapsed: {elapsed_nested_module_symbol}')
# Out:
# Elapsed: 4.56574897095561

# %%
import os

def create_module_file(module_name, **kwargs):
    """Create a module file named <module_name>.py
    Module has a single function (print_values) that will print
    out the supplied (stringified) kwargs
    """

    module_file_name = f'{module_name}.py'
    module_rel_file_path = module_file_name
    module_abs_file_path = os.path.abspath(module_rel_file_path)

    with open(module_abs_file_path, 'w') as f:
        f.write(f'# {module_name}.py\n\n')
        f.write(f"print('running {module_file_name}...')\n\n")
        f.write(f'def print_values():\n')
        for key, value in kwargs.items():
            f.write(f"\tprint('{str(key)}', '{str(value)}')\n")

# %%
create_module_file('test1', k1=10, k2=40)

# %%
import test1
# Out:
# running test1.py...

# %%
test1.print_values()
# Out:
# k1 10
# k2 40

# %%
create_module_file('test1', k1=10, k2=40, k3='cheese')

# %%
import test1

# %%
test1.print_values()
# Out:
# k1 10
# k2 40

# %%
import sys

'test1' in sys.modules
# Out:
# True

# %%
del sys.modules['test1']

import test1
# Out:
# running test1.py...

# %%
test1.print_values()
# Out:
# k1 10
# k2 40
# k3 cheese

# %%
create_module_file('test1', k1=10, k2=40, k3='cheese', k4 = 'bread')

# %%
import importlib
importlib.reload(test1)
# Out:
# running test1.py...
# <module 'test1' from '/home/jovyan/work/test1.py'>

# %%
test1.print_values()
# Out:
# k1 10
# k2 40
# k3 cheese
# k4 bread

# %%
import sys

# %%
sys.path
# Out:
# ['/home/jovyan',
#  '/usr/local/lib/python37.zip',
#  '/usr/local/lib/python3.7',
#  '/usr/local/lib/python3.7/lib-dynload',
#  '',
#  '/opt/venv/lib/python3.7/site-packages',
#  '/opt/venv/lib/python3.7/site-packages/python_language_server-deepnote_0.03-py3.7.egg',
#  '/opt/venv/lib/python3.7/site-packages/ujson-4.0.1-py3.7-linux-x86_64.egg',
#  '/opt/venv/lib/python3.7/site-packages/pluggy-1.0.0.dev0-py3.7.egg',
#  '/opt/venv/lib/python3.7/site-packages/python_jsonrpc_server-0.4.0-py3.7.egg',
#  '/opt/venv/lib/python3.7/site-packages/IPython/extensions',
#  '/home/jovyan/.ipython',
#  '/home/jovyan/work',
#  '/home/jovyan/work/Session_11/examplen',
#  '/home/jovyan/work/Session_11/examplen',
#  '/home/jovyan/work/Session_11/examplen',
#  '/home/jovyan/work/Session_11/examplen']

# %%
# !pwd
# Out:
# /home/jovyan/work

# %%
importlib.util.find_spec('modulen')

# %%
sys.path.append('/home/jovyan/work/Session_11/examplem')

# %%
importlib.util.find_spec('modulem')
# Out:
# ModuleSpec(name='modulem', loader=<_frozen_importlib_external.SourceFileLoader object at 0x7fc02dc616d0>, origin='/home/jovyan/work/Session_11/examplem/modulem.py')

# %%
len(sys.path)
# Out:
# 18

# %%
sys.path
# Out:
# ['/home/jovyan',
#  '/usr/local/lib/python37.zip',
#  '/usr/local/lib/python3.7',
#  '/usr/local/lib/python3.7/lib-dynload',
#  '',
#  '/opt/venv/lib/python3.7/site-packages',
#  '/opt/venv/lib/python3.7/site-packages/python_language_server-deepnote_0.03-py3.7.egg',
#  '/opt/venv/lib/python3.7/site-packages/ujson-4.0.1-py3.7-linux-x86_64.egg',
#  '/opt/venv/lib/python3.7/site-packages/pluggy-1.0.0.dev0-py3.7.egg',
#  '/opt/venv/lib/python3.7/site-packages/python_jsonrpc_server-0.4.0-py3.7.egg',
#  '/opt/venv/lib/python3.7/site-packages/IPython/extensions',
#  '/home/jovyan/.ipython',
#  '/home/jovyan/work',
#  '/home/jovyan/work/Session_11/examplen',
#  '/home/jovyan/work/Session_11/examplen',
#  '/home/jovyan/work/Session_11/examplen',
#  '/home/jovyan/work/Session_11/examplen',
#  '/home/jovyan/work/Session_11/examplem']

# %%
sys.path = sys.path[:-5]

# %%
sys.path
# Out:
# ['/home/jovyan',
#  '/usr/local/lib/python37.zip',
#  '/usr/local/lib/python3.7',
#  '/usr/local/lib/python3.7/lib-dynload',
#  '',
#  '/opt/venv/lib/python3.7/site-packages',
#  '/opt/venv/lib/python3.7/site-packages/python_language_server-deepnote_0.03-py3.7.egg',
#  '/opt/venv/lib/python3.7/site-packages/ujson-4.0.1-py3.7-linux-x86_64.egg',
#  '/opt/venv/lib/python3.7/site-packages/pluggy-1.0.0.dev0-py3.7.egg',
#  '/opt/venv/lib/python3.7/site-packages/python_jsonrpc_server-0.4.0-py3.7.egg',
#  '/opt/venv/lib/python3.7/site-packages/IPython/extensions',
#  '/home/jovyan/.ipython',
#  '/home/jovyan/work']

# %%
sys.path.append('/home/jovyan/work/Session_11/examplen')

# %% [markdown]
# /home/jovyan/work/Session_11/examplen

# %%
importlib.util.find_spec('modulen')

# %%
sys.path.append('/home/jovyan/work/Session_11/examplem')

# %%
importlib.util.find_spec('modulem')
# Out:
# ModuleSpec(name='modulem', loader=<_frozen_importlib_external.SourceFileLoader object at 0x7fc02dc61a90>, origin='/home/jovyan/work/Session_11/examplem/modulem.py')
